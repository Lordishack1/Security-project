# %%
import pandas as pd
from tld import get_tld
import tldextract

tranco_df = pd.read_csv("tranco_Y5G4G.csv")
phishTank_df = pd.read_csv("PhishTank-online-banking-phishing-urls-final.csv")
majestic_df = pd.read_csv("majestic_million.csv")
master_list_df = pd.read_csv("c2-allmasterlist-high.txt")

# %%
new_row = pd.DataFrame({'1':1, 'google.com':'google.com'}, index=[0])
tranco_df = pd.concat([new_row, tranco_df]).reset_index(drop = True)
tranco_df.rename(columns = {'1':'Rank'}, inplace = True)
tranco_df.rename(columns = {'google.com':'Domain'}, inplace = True)

# %%
Domain_no_TLD = []
Domain_len_list = []
Domain_no_list = []
len_list = []
digit_count_list = []
for x in tranco_df["Domain"]:
    this = x.split('.')
    Domain_no_list.append(len(this[0]))
    Domain_no_TLD.append(this[0])
tranco_df["Domain no TLD"] = Domain_no_TLD
tranco_df["Domain no TLD len"] = Domain_no_list

for x in tranco_df["Domain"]:
    if len(x) <= 5 and len(x) >= 1:
        len_list.append("1-5")
    elif len(x) >= 6 and len(x) <= 10:
        len_list.append("6-10")
    elif len(x) >= 11 and len(x) <= 15:
        len_list.append("11-15")
    elif len(x) >= 16:
        len_list.append("16+")
    z = 0
    for y in x:
        if y == '0' or y == "1" or y == "2"or y == "3" or y == "4" or y == "5" or y == "6" or y == "7" or y == "8" or y == "9":
            z = z + 1
        else:
            z = z
    digit_count_list.append(z)
    Domain_len_list.append(len(x))

tranco_df["Domain Len"] = Domain_len_list
tranco_df["Grouped Len"] = len_list
tranco_df["digit count"] = digit_count_list
tranco_df.head(100)
# Out:
#     Rank         Domain Domain no TLD  Domain no TLD len  Domain Len  \
# 0      1     google.com        google                  6          10
# 1      2   facebook.com      facebook                  8          12
# 2      3   a-msedge.net      a-msedge                  8          12
# 3      4    youtube.com       youtube                  7          11
# 4      5  microsoft.com     microsoft                  9          13
# ..   ...            ...           ...                ...         ...
# 95    96    myfritz.net       myfritz                  7          11
# 96    97       ebay.com          ebay                  4           8
# 97    98  google.com.hk        google                  6          13
# 98    99    nytimes.com       nytimes                  7          11
# 99   100     fandom.com        fandom                  6          10
#
#    Grouped Len  digit count
# 0         6-10            0
# 1        11-15            0
# 2        11-15            0
# 3        11-15            0
# 4        11-15            0
# ..         ...          ...
# 95       11-15            0
# 96        6-10            0
# 97       11-15            0
# 98       11-15            0
# 99        6-10            0
#
# [100 rows x 7 columns]

# %%
def is_ip(address):
    return address.replace('.', '').isnumeric()
hostname_list = []
ip_address_list = []
domain_list = []
domain_list_len = []
len_list = []
digit_count_list = []
for url in phishTank_df['Indicator']:
    hostname_with_path = url.split("//")[1]
    hostname_only = hostname_with_path.split("/")[0]
    if is_ip(hostname_only):
        ip_address_list.append(hostname_only)
    else:
        hostname_list.append(hostname_only)
        domain = tldextract.extract(hostname_only).domain
        if len(domain) <= 5 and len(domain) >= 1:
            len_list.append("1-5")
        elif len(domain) >= 6 and len(domain) <= 10:
            len_list.append("6-10")
        elif len(domain) >= 11 and len(domain) <= 15:
            len_list.append("11-15")
        elif len(domain) >= 16:
            len_list.append("16+")
        z = 0
        for y in domain:
            if y == '0' or y == "1" or y == "2"or y == "3" or y == "4" or y == "5" or y == "6" or y == "7" or y == "8" or y == "9":
                z = z + 1
            else:
                z = z
        digit_count_list.append(z)
        domain_list_len.append(len(domain))
        domain_list.append(domain)

phishTank_new_df = pd.DataFrame(hostname_list, columns=['hostname'])
phishTank_new_df['domain'] = domain_list
phishTank_new_df['domain length'] = domain_list_len
phishTank_new_df['Grouped Len'] = len_list
phishTank_new_df['digit count'] = digit_count_list
phishTank_new_df.sample(n=100)
# Out:
#                      hostname                domain  domain length  \
# 104  momentumsurfandskate.com  momentumsurfandskate             20
# 89    www.portugalkaraoke.com       portugalkaraoke             15
# 216         www.asianstss.org             asianstss              9
# 336       bankohlventures.com       bankohlventures             15
# 359               bclbank.com               bclbank              7
# ..                        ...                   ...            ...
# 381                 minhon.pt                minhon              6
# 241   greeneandassociates.biz   greeneandassociates             19
# 209           xarabank.com.mt              xarabank              8
# 227    www.qualityhandles.com        qualityhandles             14
# 12          allstarprintz.com         allstarprintz             13
#
#     Grouped Len  digit count
# 104         16+            0
# 89        11-15            0
# 216        6-10            0
# 336       11-15            0
# 359        6-10            0
# ..          ...          ...
# 381        6-10            0
# 241         16+            0
# 209        6-10            0
# 227       11-15            0
# 12        11-15            0
#
# [100 rows x 5 columns]

# %%
Domain_no_TLD = []
Domain_len_list = []
digit_count_list = []
unique_list = []
for x in majestic_df["Domain"]:
    this = x.split('.')
    Domain_len_list.append(len(this[0]))
    Domain_no_TLD.append(this[0])
    
majestic_df["Domain no TLD"] = Domain_no_TLD
majestic_df["Domain len"] = Domain_len_list
majestic_df.head(100)

Domain_TLD_len_list = []
len_list = []
for x in majestic_df["Domain"]:
    Domain_TLD_len_list.append(len(x))
    if len(x) <= 5 and len(x) >= 1:
        len_list.append("1-5")
    elif len(x) >= 6 and len(x) <= 10:
        len_list.append("6-10")
    elif len(x) >= 11 and len(x) <= 15:
        len_list.append("11-15")
    elif len(x) >= 16:
        len_list.append("16+")
    z = 0
    for y in x:
        if y == '0' or y == "1" or y == "2"or y == "3" or y == "4" or y == "5" or y == "6" or y == "7" or y == "8" or y == "9":
            z = z + 1
        else:
            z = z
    digit_count_list.append(z)
majestic_df["Domain TLD len"] = Domain_TLD_len_list
majestic_df['Grouped Len'] = len_list
majestic_df['digit count'] = digit_count_list
majestic_df.head(100)
# Out:
#     GlobalRank  TldRank                Domain  TLD  RefSubNets   RefIPs  \
# 0            1        1            google.com  com      493225  2423262
# 1            2        2          facebook.com  com      491991  2576708
# 2            3        3           youtube.com  com      443833  2089772
# 3            4        4           twitter.com  com      437495  2073037
# 4            5        5         instagram.com  com      375641  1733941
# ..         ...      ...                   ...  ...         ...      ...
# 95          96       66  youtube-nocookie.com  com       84737   208923
# 96          97       67             nginx.com  com       84535   165377
# 97          98       68              imdb.com  com       84275   218180
# 98          99       69         bloomberg.com  com       84239   196751
# 99         100        1           harvard.edu  edu       84049   193996
#
#               IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0             google.com     com               1            1          492684
# 1           facebook.com     com               2            2          491669
# 2            youtube.com     com               3            3          443324
# 3            twitter.com     com               4            4          437045
# 4          instagram.com     com               5            5          375337
# ..                   ...     ...             ...          ...             ...
# 95  youtube-nocookie.com     com              97           67           84689
# 96             nginx.com     com              98           68           84405
# 97              imdb.com     com              99           69           84297
# 98         bloomberg.com     com             100           70           84164
# 99           harvard.edu     edu             101            1           84006
#
#     PrevRefIPs     Domain no TLD  Domain len  Domain TLD len Grouped Len  \
# 0      2421905            google           6              10        6-10
# 1      2574466          facebook           8              12       11-15
# 2      2088013           youtube           7              11       11-15
# 3      2071411           twitter           7              11       11-15
# 4      1733107         instagram           9              13       11-15
# ..         ...               ...         ...             ...         ...
# 95      208896  youtube-nocookie          16              20         16+
# 96      165050             nginx           5               9        6-10
# 97      218127              imdb           4               8        6-10
# 98      196873         bloomberg           9              13       11-15
# 99      194097           harvard           7              11       11-15
#
#     digit count
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 95            0
# 96            0
# 97            0
# 98            0
# 99            0
#
# [100 rows x 17 columns]

# %%
new_master_list_df = pd.DataFrame(master_list_df['Domain'])
Domain_len_list =[]
len_list = []
digit_count_list = []
for x in new_master_list_df['Domain']:
    if len(x) <= 5 and len(x) >= 1:
        len_list.append("1-5")
    elif len(x) >= 6 and len(x) <= 10:
        len_list.append("6-10")
    elif len(x) >= 11 and len(x) <= 15:
        len_list.append("11-15")
    elif len(x) >= 16:
        len_list.append("16+")
    z = 0
    for y in x:
        if y == '0' or y == "1" or y == "2"or y == "3" or y == "4" or y == "5" or y == "6" or y == "7" or y == "8" or y == "9":
            z = z + 1
        else:
            z = z
    digit_count_list.append(z)
    Domain_len_list.append(len(x))
    
new_master_list_df["Domain Len"] = Domain_len_list
new_master_list_df['Grouped Len'] = len_list
new_master_list_df['digit count'] = digit_count_list
new_master_list_df.head(100)
# Out:
#                  Domain  Domain Len Grouped Len  digit count
# 0    ns1.backdates0.org          18         16+            2
# 1   ns1.backdates10.com          19         16+            3
# 2   ns1.backdates12.com          19         16+            3
# 3   ns1.backdates14.com          19         16+            3
# 4   ns1.backdates18.com          19         16+            3
# ..                  ...         ...         ...          ...
# 95    ngbmfsbuql.yi.org          17         16+            0
# 96          oalierb.com          11       11-15            0
# 97     pcajqcaof.yi.org          16         16+            0
# 98    qpyosxkmcc.yi.org          17         16+            0
# 99     qwzsprieo.yi.org          16         16+            0
#
# [100 rows x 4 columns]

# %%
tranco_df['Grouped Len'].head(100).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
phishTank_new_df['Grouped Len'].head(100).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
majestic_df['Grouped Len'].head(100).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
new_master_list_df['Grouped Len'].head(100).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Yes the average domain length for malicious is much larger than good urls

# %%
def count_unique_chars(domain):
    tld = domain.split('.')[-1]
    domain_no_tld = domain[:-len(tld)-1]
    unique_chars = set(domain_no_tld)
    return len(unique_chars)

tranco_df["unique char count"] = tranco_df['Domain'].apply(count_unique_chars)
tranco_df.head(100)
# Out:
#     Rank         Domain Domain no TLD  Domain no TLD len  Domain Len  \
# 0      1     google.com        google                  6          10
# 1      2   facebook.com      facebook                  8          12
# 2      3   a-msedge.net      a-msedge                  8          12
# 3      4    youtube.com       youtube                  7          11
# 4      5  microsoft.com     microsoft                  9          13
# ..   ...            ...           ...                ...         ...
# 95    96    myfritz.net       myfritz                  7          11
# 96    97       ebay.com          ebay                  4           8
# 97    98  google.com.hk        google                  6          13
# 98    99    nytimes.com       nytimes                  7          11
# 99   100     fandom.com        fandom                  6          10
#
#    Grouped Len  digit count  unique char count
# 0         6-10            0                  4
# 1        11-15            0                  7
# 2        11-15            0                  7
# 3        11-15            0                  6
# 4        11-15            0                  8
# ..         ...          ...                ...
# 95       11-15            0                  7
# 96        6-10            0                  4
# 97       11-15            0                  7
# 98       11-15            0                  7
# 99        6-10            0                  6
#
# [100 rows x 8 columns]

# %%
phishTank_new_df["unique char count"] = phishTank_new_df['hostname'].apply(count_unique_chars)
phishTank_new_df.head(100)
# Out:
#                        hostname              domain  domain length  \
# 0          vysodagiva0.xhost.ro               xhost              5
# 1        woodfloorcreations.com  woodfloorcreations             18
# 2              hghsuppliers.com        hghsuppliers             12
# 3         marcaldeataide.com.br      marcaldeataide             14
# 4   citymarket.imperiavkusov.ru       imperiavkusov             13
# ..                          ...                 ...            ...
# 95                   ehss.co.th                ehss              4
# 96     www.scatolificiogiani.it   scatolificiogiani             17
# 97         www.familylifebc.com        familylifebc             12
# 98                   foundus.my             foundus              7
# 99                   foundus.my             foundus              7
#
#    Grouped Len  digit count  unique char count
# 0          1-5            0                 13
# 1          16+            0                 13
# 2        11-15            0                  9
# 3        11-15            0                 11
# 4        11-15            0                 15
# ..         ...          ...                ...
# 95         1-5            0                  6
# 96         16+            0                 12
# 97       11-15            0                 11
# 98        6-10            0                  6
# 99        6-10            0                  6
#
# [100 rows x 6 columns]

# %%
majestic_df["unique char count"] = majestic_df['Domain'].apply(count_unique_chars)
majestic_df.head(100)
# Out:
#     GlobalRank  TldRank                Domain  TLD  RefSubNets   RefIPs  \
# 0            1        1            google.com  com      493225  2423262
# 1            2        2          facebook.com  com      491991  2576708
# 2            3        3           youtube.com  com      443833  2089772
# 3            4        4           twitter.com  com      437495  2073037
# 4            5        5         instagram.com  com      375641  1733941
# ..         ...      ...                   ...  ...         ...      ...
# 95          96       66  youtube-nocookie.com  com       84737   208923
# 96          97       67             nginx.com  com       84535   165377
# 97          98       68              imdb.com  com       84275   218180
# 98          99       69         bloomberg.com  com       84239   196751
# 99         100        1           harvard.edu  edu       84049   193996
#
#               IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0             google.com     com               1            1          492684
# 1           facebook.com     com               2            2          491669
# 2            youtube.com     com               3            3          443324
# 3            twitter.com     com               4            4          437045
# 4          instagram.com     com               5            5          375337
# ..                   ...     ...             ...          ...             ...
# 95  youtube-nocookie.com     com              97           67           84689
# 96             nginx.com     com              98           68           84405
# 97              imdb.com     com              99           69           84297
# 98         bloomberg.com     com             100           70           84164
# 99           harvard.edu     edu             101            1           84006
#
#     PrevRefIPs     Domain no TLD  Domain len  Domain TLD len Grouped Len  \
# 0      2421905            google           6              10        6-10
# 1      2574466          facebook           8              12       11-15
# 2      2088013           youtube           7              11       11-15
# 3      2071411           twitter           7              11       11-15
# 4      1733107         instagram           9              13       11-15
# ..         ...               ...         ...             ...         ...
# 95      208896  youtube-nocookie          16              20         16+
# 96      165050             nginx           5               9        6-10
# 97      218127              imdb           4               8        6-10
# 98      196873         bloomberg           9              13       11-15
# 99      194097           harvard           7              11       11-15
#
#     digit count  unique char count
# 0             0                  4
# 1             0                  7
# 2             0                  6
# 3             0                  5
# 4             0                  8
# ..          ...                ...
# 95            0                 11
# 96            0                  4
# 97            0                  4
# 98            0                  7
# 99            0                  5
#
# [100 rows x 18 columns]

# %%
new_master_list_df["unique char count"] = new_master_list_df['Domain'].apply(count_unique_chars)
new_master_list_df.head(100)
# Out:
#                  Domain  Domain Len Grouped Len  digit count  \
# 0    ns1.backdates0.org          18         16+            2
# 1   ns1.backdates10.com          19         16+            3
# 2   ns1.backdates12.com          19         16+            3
# 3   ns1.backdates14.com          19         16+            3
# 4   ns1.backdates18.com          19         16+            3
# ..                  ...         ...         ...          ...
# 95    ngbmfsbuql.yi.org          17         16+            0
# 96          oalierb.com          11       11-15            0
# 97     pcajqcaof.yi.org          16         16+            0
# 98    qpyosxkmcc.yi.org          17         16+            0
# 99     qwzsprieo.yi.org          16         16+            0
#
#     unique char count
# 0                  12
# 1                  12
# 2                  12
# 3                  12
# 4                  12
# ..                ...
# 95                 12
# 96                  7
# 97                 10
# 98                 11
# 99                 11
#
# [100 rows x 5 columns]

# %%
def top_3_TLDs(group):
    tld_counts = group.str.split('.').str[-1].value_counts(normalize=True)
    return tld_counts[:3].apply(lambda x: f'{x:.2%}')

result = tranco_df.head(100).groupby('Grouped Len')['Domain'].apply(top_3_TLDs)
print(result)
# Out:
# Grouped Len
# 1-5          co     100.00%
# 11-15        com     56.10%
#              net     31.71%
#              org      7.32%
# 16+          com     72.73%
#              net     27.27%
# 6-10         com     68.09%
#              net     12.77%
#              ru       4.26%
# Name: Domain, dtype: object

# %%
result = phishTank_new_df.head(100).groupby('Grouped Len')['hostname'].apply(top_3_TLDs)
print(result)
# Out:
# Grouped Len
# 1-5          com    28.57%
#              ro     14.29%
#              net    14.29%
# 11-15        com    47.50%
#              org    17.50%
#              br     10.00%
# 16+          com    72.73%
#              org     9.09%
#              my      4.55%
# 6-10         com    41.94%
#              net    16.13%
#              my      9.68%
# Name: hostname, dtype: object

# %%
result = majestic_df.head(100).groupby('Grouped Len')['Domain'].apply(top_3_TLDs)
print(result)
# Out:
# Grouped Len
# 1-5          me     66.67%
#              co     33.33%
# 11-15        com    75.68%
#              org    13.51%
#              cn      2.70%
# 16+          com    73.68%
#              org    15.79%
#              cn      5.26%
# 6-10         com    65.85%
#              org     7.32%
#              gov     4.88%
# Name: Domain, dtype: object

# %%
result = new_master_list_df.head(100).groupby('Grouped Len')['Domain'].apply(top_3_TLDs)
print(result)
# Out:
# Grouped Len
# 11-15        com    58.14%
#              org    20.93%
#              net     9.30%
# 16+          com    59.65%
#              org    31.58%
#              net     8.77%
# Name: Domain, dtype: object
