# %% [markdown]
# # Lab 1 - Keyword Generation from the domain name of a website

# %%
# !pip install wordsegment
# Out:
# Requirement already satisfied: wordsegment in /Users/IsaacStertzbach/opt/anaconda3/lib/python3.9/site-packages (1.3.1)

# %%
# list of imports needed #
import wordsegment #
from wordsegment import load, segment
import csv # pip install python-csv (if not installed)
import pandas as pd

# %%
#Lab Instructions: 
# For this lab you are given a list of X number of websites
# and your task is to generate a csv file of keywords you 
# can generate from the domain name strings, with the count how many words are found.
# To accomplish this task you need to:

#input www.google.com -> google -> goes in the final csv file with 'google' as a keyword count

# %% [markdown]
# # Task 1) Load your data set into your python file

# %%
# load the data in python pandas
url_df = pd.read_csv("inputurls.csv")
url_df
# Out:
#                                     urls
# 0                    https://youtube.com
# 1                     https://github.com
# 2              https://stackoverflow.com
# 3                    https://nordvpn.com
# 4                https://myanimelist.net
# 5                     https://amazon.com
# 6        https://napavalleytoukraine.org
# 7          https://sunflower-ukraine.org
# 8              https://theukrainewar.org
# 9         https://goalsforukraine.hockey
# 10          https://ukraine-donation.net
# 11               https://ukraine-dev.pro
# 12  https://clevedonukrainiansupport.org
# 13          https://heartsforukraine.net
# 14           https://mission-ukraine.org
# 15           https://pucksforukraine.com
# 16         https://peopleforukraine.info
# 17             https://ukraineassist.org

# %% [markdown]
# # Task 2) Choose a data structure to store the keywords you are creating (Recomend using a python dictionary)

# %%
#Example of declaring empty dictionary: wordDic = {} 
wordDic = {}

# %% [markdown]
# # Task 3) Loop through the data, creating your keywords and storing them in your data structure

# %%
# get the URL from the given given input_url.csv file
# get the domain name part from the url by splitting with . character and get url[0]. 
#Example: if url = 'https://www.google.com/path' the domain name part is domain= 'google' 
#and tld = 'com'
# for each url find domain name part (url should be iterated from the given dataset)
wordCount = 0
keyword_list = []
domain_list = []
for x in url_df["urls"]:
    fun = x.split('.')
    y = fun[0].split("//")
    domain = y[1]
    domain_list.append(domain)
    load()
    keywords = segment(domain)
    keyword_list.append(keywords)
    for key in keywords:
        if key in wordDic:
            wordDic[key] += 1
            wordCount += 1  
        else:
            wordDic[key] = 1
url_df["domain"] = domain_list
url_df["keyword_list"] = keyword_list
url_df
#for each domain part run the following in a loop

# use this following code to generate keywords from the domain names part using segment
#url= 'https://google.com'
#domain='google'
#load()
#keywords = segment(domain)
#print(keywords)


# loop thorugh the len of keywords list
# strip the keywords to remove characters like - or . [hint .strip() functions]
# for each word in keyword list, add it into a wordDic dictionary
# if new word then add it as count 1, but if repeating keyword then update the current count
# from i to i+1. 
# example: 
#if word in wordDic: # if word is present in dictionary updating the count
    #wordDic[word] += 1
#else:
    #wordDic[word] = 1 # if new word then inserting it in dictionary     

#Next you update the word count as
#    wordCount = wordCount + 1

#Print the wordDic to check if it is updated
#print(wordDic)
# Out:
#                                     urls                    domain  \
# 0                    https://youtube.com                   youtube
# 1                     https://github.com                    github
# 2              https://stackoverflow.com             stackoverflow
# 3                    https://nordvpn.com                   nordvpn
# 4                https://myanimelist.net               myanimelist
# 5                     https://amazon.com                    amazon
# 6        https://napavalleytoukraine.org       napavalleytoukraine
# 7          https://sunflower-ukraine.org         sunflower-ukraine
# 8              https://theukrainewar.org             theukrainewar
# 9         https://goalsforukraine.hockey           goalsforukraine
# 10          https://ukraine-donation.net          ukraine-donation
# 11               https://ukraine-dev.pro               ukraine-dev
# 12  https://clevedonukrainiansupport.org  clevedonukrainiansupport
# 13          https://heartsforukraine.net          heartsforukraine
# 14           https://mission-ukraine.org           mission-ukraine
# 15           https://pucksforukraine.com           pucksforukraine
# 16         https://peopleforukraine.info          peopleforukraine
# 17             https://ukraineassist.org             ukraineassist
#
#                       keyword_list
# 0                        [youtube]
# 1                       [git, hub]
# 2                [stack, overflow]
# 3                      [nord, vpn]
# 4                [my, anime, list]
# 5                         [amazon]
# 6      [napa, valley, to, ukraine]
# 7             [sunflower, ukraine]
# 8              [the, ukraine, war]
# 9            [goals, for, ukraine]
# 10             [ukraine, donation]
# 11                  [ukraine, dev]
# 12  [clevedon, ukrainian, support]
# 13          [hearts, for, ukraine]
# 14              [mission, ukraine]
# 15           [pucks, for, ukraine]
# 16          [people, for, ukraine]
# 17               [ukraine, assist]

# %% [markdown]
# # Task 4) When the loop is over you need to output your keywords into a csv file

# %%
with open("csvFile.csv",'w') as f:
    writer = csv.writer(f)    
    for key in wordDic.keys():
        writer.writerow("%s,%s\n"%(key,wordDic[key])) # write both key and the value from wordDic dictionary
    f.close()
